# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Read data from web-page
# Read data of inflation from web page with url: [inflation](https://xn----ctbjnaatncev9av3a8f8b.xn--p1ai/%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86%D1%8B-%D0%B8%D0%BD%D1%84%D0%BB%D1%8F%D1%86%D0%B8%D0%B8)
#
# Because of data reads to list file we export them to dataframe

# %%
url = "https://xn----ctbjnaatncev9av3a8f8b.xn--p1ai/%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86%D1%8B-%D0%B8%D0%BD%D1%84%D0%BB%D1%8F%D1%86%D0%B8%D0%B8"
df = pd.read_html(url)

# %%
inflation = pd.DataFrame(df[0])

# %%
inflation.head()
# Out:
#     Год    Янв    Фев    Мар    Апр    Май    Июн    Июл    Авг    Сен    Окт  \
# 0  2024   7.44   7.67    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1  2023  11.76  10.97   3.51   2.30   2.50   3.24   4.30   5.13   6.00   6.68
# 2  2022   8.74   9.16  16.70  17.83  17.11  15.90  15.09  14.30  13.67  12.63
# 3  2021   5.19   5.67   5.78   5.52   6.01   6.51   6.47   6.69   7.41   8.14
# 4  2020   2.42   2.31   2.55   3.10   3.03   3.21   3.37   3.57   3.67   3.98
#
#      Ноя    Дек  Всего
# 0    NaN    NaN   1.55
# 1   7.47   7.42   7.42
# 2  11.97  11.92  11.92
# 3   8.40   8.39   8.39
# 4   4.42   4.91   4.91

# %% [markdown]
# ## Read data about salary from xlsx file
# Для корректного чтени данных, они были подкорректированы внутри ексель файла:
# * были удалены первые две строки для корректного чтения данных;
# * были скорректированы названия стобцов, так как они были с надстрочными символами;
# * были удалены сноски

# %%
salary = pd.read_excel("data/Rosstat Labor Market 2023.xlsx", sheet_name = None, skiprows=2)

# %%
salary_df_1 = pd.DataFrame(salary['sheet1'])

# %%
salary_df_1.columns
# Out:
# Index(['год',  2000,  2001,  2002,  2003,  2004,  2005,  2006,  2007,  2008,
#         2009,  2010,  2011,  2012,  2013,  2014,  2015,  2016],
#       dtype='object')

# %%
salary_df_1 = salary_df_1.rename(columns={'год':'Area'})

# %%
salary_df_1.columns
# Out:
# Index(['Area',   2000,   2001,   2002,   2003,   2004,   2005,   2006,   2007,
#          2008,   2009,   2010,   2011,   2012,   2013,   2014,   2015,   2016],
#       dtype='object')

# %%
salary_df_2 = pd.DataFrame(salary['sheet2'])
salary_df_2.columns
# Out:
# Index(['год', 2017, 2018, 2019, 2020, 2021, 2022, 2023], dtype='object')

# %%
salary_df_2 = salary_df_2.rename(columns={'год':'Area'})

# %%
salary_df_2.columns
# Out:
# Index(['Area', 2017, 2018, 2019, 2020, 2021, 2022, 2023], dtype='object')

# %% [markdown]
# ## Select the areas of interest:
#
# * Рыболовство и рыбоводство
# * Строительство
# * Добыча полезных исскопаемых

# %%
areas = ['Рыболовство, рыбоводство', 'Строительство', 'Добыча полезных ископаемых']
salary_interest_area = salary_df_1[salary_df_1['Area'].isin(areas)].copy().reset_index(drop = True)
salary_interest_area
# Out:
#                          Area    2000    2001     2002     2003     2004  \
# 0    Рыболовство, рыбоводство  2845.6  3839.3   5031.3   5444.5   7084.9
# 1  Добыча полезных ископаемых  5940.2  9099.2  11080.9  13912.4  16841.7
# 2               Строительство  2639.8  3859.3   4806.9   6176.7   7304.7
#
#       2005     2006     2007     2008     2009     2010     2011     2012  \
# 0  10233.5  12310.8  14797.0  19498.9  22913.5  23781.9  25939.9  29201.4
# 1  19726.9  23145.2  28107.5  33206.1  35363.4  39895.0  45132.0  50400.6
# 2   9042.8  10869.2  14333.4  18574.0  18122.2  21171.7  23682.0  25950.6
#
#       2013     2014     2015     2016
# 0  32437.3  37062.0  46676.0  54927.0
# 1  54161.2  58959.0  63695.0  69936.0
# 2  27701.4  29354.0  29960.0  32332.0

# %%
salary_interest_area_1 = salary_df_2[salary_df_2['Area'].isin(areas)].copy().reset_index(drop=True)
salary_interest_area_1
# Out:
#                          Area     2017     2018     2019     2020      2021  \
# 0    Рыболовство, рыбоводство  68032.0  75766.0  88603.8  94983.0  101547.4
# 1  Добыча полезных ископаемых  74474.1  83178.0  89343.7  95359.0  103473.5
# 2               Строительство  33677.9  38518.0  42629.9  44738.0   51944.2
#
#        2022      2023
# 0  121726.2  139520.0
# 1  118375.7  130825.6
# 2   60849.5   68944.4

# %%
all_interested_areas = pd.concat([salary_interest_area, salary_interest_area_1.drop(columns=['Area'])], axis=1)

# %% [markdown]
# Создан датафрейм с интересующими меня сферами и зарплатами по годам

# %%
all_interested_areas
# Out:
#                          Area    2000    2001     2002     2003     2004  \
# 0    Рыболовство, рыбоводство  2845.6  3839.3   5031.3   5444.5   7084.9
# 1  Добыча полезных ископаемых  5940.2  9099.2  11080.9  13912.4  16841.7
# 2               Строительство  2639.8  3859.3   4806.9   6176.7   7304.7
#
#       2005     2006     2007     2008  ...     2014     2015     2016  \
# 0  10233.5  12310.8  14797.0  19498.9  ...  37062.0  46676.0  54927.0
# 1  19726.9  23145.2  28107.5  33206.1  ...  58959.0  63695.0  69936.0
# 2   9042.8  10869.2  14333.4  18574.0  ...  29354.0  29960.0  32332.0
#
#       2017     2018     2019     2020      2021      2022      2023
# 0  68032.0  75766.0  88603.8  94983.0  101547.4  121726.2  139520.0
# 1  74474.1  83178.0  89343.7  95359.0  103473.5  118375.7  130825.6
# 2  33677.9  38518.0  42629.9  44738.0   51944.2   60849.5   68944.4
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Plot salaries

# %%
inf_from_1999 = inflation[['Год','Всего']][:26]

# %%
years = all_interested_areas.columns[1:].astype(int)
for area in all_interested_areas['Area']:
  salary = all_interested_areas[all_interested_areas['Area']==area].values[0][1:]
  plt.plot(years, salary)
  plt.title(f'Зарплата в сфере: {area}')
  plt.ylabel("Рублей")
  plt.grid(True)
  plt.show()

# %% [markdown]
# Из данных графиков можно сделать вывод о том, что ежегодно зарплаты в данных сферах растут. Причной может быть выход страны на мировой рынок.
#
# Также в среднем уровень жизни в стране с 2000-го года поднялся, из чего может следовать рост спроса и внутри страны тоже.
#
# Также не стоит забывать о нескольких пережитых кризисах. Рост зарплат может быть связан с инфляцией. Поскольку уровень инфляции увеличивает цены на товары и услуги, работники могут требовать повышения зарплаты, чтобы компенсировать ухудшение покупательной способности своих доходов.

# %% [markdown]
# ### Salaries with inflation

# %%
years
# Out:
# Index([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#       dtype='int64')

# %% [markdown]
# Пересчет зарплаты текущего года к прошлому происходит по следующей формуле:
#
# $salaryrecalc = (\frac{salary}{1+0.01*inflation_{prev\_year}})$
#
# где
#
# $salaryrecalc$ – зарплата за текущий год
#
# $salary$ – зарплата за текущий год с учетом инфляции
#
# $inflation_{prev\_year}$ – коэффициент инфляции за предыдущий год

# %%
all_interested_areas
# Out:
#                          Area    2000    2001     2002     2003     2004  \
# 0    Рыболовство, рыбоводство  2845.6  3839.3   5031.3   5444.5   7084.9
# 1  Добыча полезных ископаемых  5940.2  9099.2  11080.9  13912.4  16841.7
# 2               Строительство  2639.8  3859.3   4806.9   6176.7   7304.7
#
#       2005     2006     2007     2008  ...     2014     2015     2016  \
# 0  10233.5  12310.8  14797.0  19498.9  ...  37062.0  46676.0  54927.0
# 1  19726.9  23145.2  28107.5  33206.1  ...  58959.0  63695.0  69936.0
# 2   9042.8  10869.2  14333.4  18574.0  ...  29354.0  29960.0  32332.0
#
#       2017     2018     2019     2020      2021      2022      2023
# 0  68032.0  75766.0  88603.8  94983.0  101547.4  121726.2  139520.0
# 1  74474.1  83178.0  89343.7  95359.0  103473.5  118375.7  130825.6
# 2  33677.9  38518.0  42629.9  44738.0   51944.2   60849.5   68944.4
#
# [3 rows x 25 columns]

# %%
years = all_interested_areas.columns[1:].astype(int)
for area in all_interested_areas['Area']:
    salary_with_inf = []
    for year in years:
        salaries = all_interested_areas[all_interested_areas['Area']==area]
        salary = salaries[year].values[0]
        curr_inf =inf_from_1999[inf_from_1999['Год']==year].values[0][1]
        prev_infl = inf_from_1999[inf_from_1999['Год']==year-1].values[0][1]
        recalc_salary = salary/(1+(prev_infl*0.01))
        salary_with_inf.append(recalc_salary)      
    fig, axs = plt.subplots(1,2)
    fig.set_size_inches(15,5)
    axs[0].plot(years, salary_with_inf ,marker= 'o', label="Зарплата с учетом инфляции")
    axs[0].plot(years, all_interested_areas[all_interested_areas['Area']==area].values[0][1:] ,marker= 's', label="Зарплата без учета инфляции")
    axs[0].set_xticks(range(2000,2024,2))
    axs[0].set_title(f"Зарплата в сфере {area} с учетом инфляции по отношению к прошлому году")
    axs[0].set_ylabel("Rub")
    axs[0].legend()
    axs[0].grid(True)
    axs[1].plot(years, inf_from_1999['Всего'].values[1:25], marker='^', c='r')
    axs[1].set_xticks(range(2000,2024,2))
    axs[1].set_ylabel("%")
    axs[1].grid(True)
    salary_with_inf.insert(0, "Реальная зарплата в сфере: " + area)
    all_interested_areas.loc["Реальная зарплата в сфере: " + area] = salary_with_inf
    #print(salary_with_inf)    
    plt.show()

# %% [markdown]
# Из графиков выше можно сделать несколько выводов:
#
# * Номинальная зарплата росла весь период
# * Реальная зарплата росла весь период, но инфляция давала о себе знать, и рост номинальной зарплаты не сглаживает роста инфляции
# * В период 2014-2015 годов, реальная зарплата в сфере "Строительство" снизилась. Причиной могло стать наложение санкций и следующее за ними снижение покупательской способности
# * Покупательская способность падает, как результат расхождения реальной и номинальной зарплаты
#
# Причинами могут быть:
#
#   * Глобальный мировой кризис
#   * Снижение цен на сырье
#   * Рост инфляции

# %% [markdown]
# ### Here are the dynamics of changes in real wages
#
# Для показания динамики, найдем процент реальной зарплаты от номинальной:
#
# $dinamyc = [1- \frac{real\_salary}{nominal\_salary}] * 100 \% $

# %%
all_interested_areas
# Out:
#                                                                                                  Area  \
# 0                                                                            Рыболовство, рыбоводство
# 1                                                                          Добыча полезных ископаемых
# 2                                                                                       Строительство
# Реальная зарплата в сфере: Рыболовство, рыбовод...  Реальная зарплата в сфере: Рыболовство, рыбово...
# Реальная зарплата в сфере: Добыча полезных иско...  Реальная зарплата в сфере: Добыча полезных иск...
# Реальная зарплата в сфере: Строительство                     Реальная зарплата в сфере: Строительство
#
#                                                            2000         2001  \
# 0                                                   2845.600000  3839.300000
# 1                                                   5940.200000  9099.200000
# 2                                                   2639.800000  3859.300000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  2083.772701  3194.093178
# Реальная зарплата в сфере: Добыча полезных иско...  4349.882835  7570.049917
# Реальная зарплата в сфере: Строительство            1933.069713  3210.732113
#
#                                                             2002  \
# 0                                                    5031.300000
# 1                                                   11080.900000
# 2                                                    4806.900000
# Реальная зарплата в сфере: Рыболовство, рыбовод...   4242.958340
# Реальная зарплата в сфере: Добыча полезных иско...   9344.661832
# Реальная зарплата в сфере: Строительство             4053.719008
#
#                                                             2003  \
# 0                                                    5444.500000
# 1                                                   13912.400000
# 2                                                    6176.700000
# Реальная зарплата в сфере: Рыболовство, рыбовод...   4731.879020
# Реальная зарплата в сфере: Добыча полезных иско...  12091.430558
# Реальная зарплата в сфере: Строительство             5368.242656
#
#                                                             2004  \
# 0                                                    7084.900000
# 1                                                   16841.700000
# 2                                                    7304.700000
# Реальная зарплата в сфере: Рыболовство, рыбовод...   6326.368426
# Реальная зарплата в сфере: Добыча полезных иско...  15038.574873
# Реальная зарплата в сфере: Строительство             6522.635950
#
#                                                             2005  \
# 0                                                   10233.500000
# 1                                                   19726.900000
# 2                                                    9042.800000
# Реальная зарплата в сфере: Рыболовство, рыбовод...   9158.313943
# Реальная зарплата в сфере: Добыча полезных иско...  17654.286737
# Реальная зарплата в сфере: Строительство             8092.715232
#
#                                                             2006  \
# 0                                                   12310.800000
# 1                                                   23145.200000
# 2                                                   10869.200000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  11099.810657
# Реальная зарплата в сфере: Добыча полезных иско...  20868.451898
# Реальная зарплата в сфере: Строительство             9800.018033
#
#                                                             2007  \
# 0                                                   14797.000000
# 1                                                   28107.500000
# 2                                                   14333.400000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  13575.229358
# Реальная зарплата в сфере: Добыча полезных иско...  25786.697248
# Реальная зарплата в сфере: Строительство            13149.908257
#
#                                                             2008  ...  \
# 0                                                   19498.900000  ...
# 1                                                   33206.100000  ...
# 2                                                   18574.000000  ...
# Реальная зарплата в сфере: Рыболовство, рыбовод...  17429.963350  ...
# Реальная зарплата в сфере: Добыча полезных иско...  29682.756771  ...
# Реальная зарплата в сфере: Строительство            16603.200143  ...
#
#                                                             2014  \
# 0                                                   37062.000000
# 1                                                   58959.000000
# 2                                                   29354.000000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  34816.345702
# Реальная зарплата в сфере: Добыча полезных иско...  55386.566463
# Реальная зарплата в сфере: Строительство            27575.387506
#
#                                                             2015  \
# 0                                                   46676.000000
# 1                                                   63695.000000
# 2                                                   29960.000000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  41914.511494
# Реальная зарплата в сфере: Добыча полезных иско...  57197.377874
# Реальная зарплата в сфере: Строительство            26903.735632
#
#                                                             2016  \
# 0                                                   54927.000000
# 1                                                   69936.000000
# 2                                                   32332.000000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  48646.709769
# Реальная зарплата в сфере: Добыча полезных иско...  61939.597910
# Реальная зарплата в сфере: Строительство            28635.196174
#
#                                                             2017  \
# 0                                                   68032.000000
# 1                                                   74474.100000
# 2                                                   33677.900000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  64558.739799
# Реальная зарплата в сфере: Добыча полезных иско...  70671.949136
# Реальная зарплата в сфере: Строительство            31958.531031
#
#                                                             2018  \
# 0                                                   75766.000000
# 1                                                   83178.000000
# 2                                                   38518.000000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  73903.628560
# Реальная зарплата в сфере: Добыча полезных иско...  81133.437378
# Реальная зарплата в сфере: Строительство            37571.205618
#
#                                                             2019  \
# 0                                                   88603.800000
# 1                                                   89343.700000
# 2                                                   42629.900000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  84975.352450
# Реальная зарплата в сфере: Добыча полезных иско...  85684.952527
# Реальная зарплата в сфере: Строительство            40884.146926
#
#                                                             2020  \
# 0                                                   94983.000000
# 1                                                   95359.000000
# 2                                                   44738.000000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  92171.761281
# Реальная зарплата в сфере: Добыча полезных иско...  92536.632703
# Реальная зарплата в сфере: Строительство            43413.876759
#
#                                                              2021  \
# 0                                                   101547.400000
# 1                                                   103473.500000
# 2                                                    51944.200000
# Реальная зарплата в сфере: Рыболовство, рыбовод...   96794.776475
# Реальная зарплата в сфере: Добыча полезных иско...   98630.731103
# Реальная зарплата в сфере: Строительство             49513.106472
#
#                                                              2022  \
# 0                                                   121726.200000
# 1                                                   118375.700000
# 2                                                    60849.500000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  112303.902574
# Реальная зарплата в сфере: Добыча полезных иско...  109212.750254
# Реальная зарплата в сфере: Строительство             56139.404004
#
#                                                              2023
# 0                                                   139520.000000
# 1                                                   130825.600000
# 2                                                    68944.400000
# Реальная зарплата в сфере: Рыболовство, рыбовод...  124660.471766
# Реальная зарплата в сфере: Добыча полезных иско...  116892.065761
# Реальная зарплата в сфере: Строительство             61601.501072
#
# [6 rows x 25 columns]

# %%
for area in all_interested_areas['Area'][:3]:
    nominal_salary = all_interested_areas[all_interested_areas['Area'] == area].values[0][1:]
    real_salary = all_interested_areas[all_interested_areas['Area'] == "Реальная зарплата в сфере: " + area].values[0][1:]
    values = (1-real_salary/nominal_salary)*100
    fig, ax = plt.subplots(figsize=(15, 5))
    ax.bar(years, values)
    
    # Отображение значений
    for bar, value in zip(ax.patches, values):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom')
    
    # Дополнительные настройки
    plt.grid(True)
    plt.title(f'Разница между реальной и номинальной заработной платой в сфере: {area}')
    plt.xticks(range(2000, 2024), rotation='vertical')
    plt.ylabel('%')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Из графиков выше мы видим, что в период с 2000 по 2018 разница между реальной и номинальной заработной платой уменьшалась с некоторыми выбросами, обусловленными частными экономическими проблемами, что говорит о том, что страна развивалась и был реальный рост доходов.
#
# Начиная с 2019 года, рост доходов прекратился.

# %% [markdown]
# ## Let's see what's going on with GDP

# %%
GDP = pd.DataFrame(pd.read_excel("data/Rosstat National Accounts 1995.xlsx", sheet_name= 1,skiprows=2))
GDP
# Out:
#         1995       1996      1997      1998       1999       2000       2001  \
# 0  1428.5221  2007.8251  2342.514  2629.623  4823.2335  7305.6463  8943.5824
#
#       2002          2003         2004          2005          2006  \
# 0  10830.5  13208.233779  17027.19086  21609.765489  26917.201375
#
#            2007          2008          2009         2010          2011
# 0  33247.513229  41276.849187  38807.218575  46308.54119  55967.226762

# %%
GDP = pd.concat([GDP, pd.DataFrame(pd.read_excel("data/Rosstat National Accounts 1995.xlsx", sheet_name= 2,skiprows=2)).drop(columns=2011)], axis=1)
GDP
# Out:
#         1995       1996      1997      1998       1999       2000       2001  \
# 0  1428.5221  2007.8251  2342.514  2629.623  4823.2335  7305.6463  8943.5824
#
#       2002          2003         2004  ...          2014          2015  \
# 0  10830.5  13208.233779  17027.19086  ...  79030.040075  83087.360055
#
#            2016          2017           2018           2019          2020  \
# 0  85616.083815  91843.154241  103861.651089  109608.305741  107658.13103
#
#            2021           2022           2023
# 0  135773.76902  155350.359037  171041.031694
#
# [1 rows x 29 columns]

# %%
GDP.columns
# Out:
# Index([1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022, 2023],
#       dtype='int64')

# %%
GDP = GDP.iloc[:, 5:]
GDP
# Out:
#         2000       2001     2002          2003         2004          2005  \
# 0  7305.6463  8943.5824  10830.5  13208.233779  17027.19086  21609.765489
#
#            2006          2007          2008          2009  ...          2014  \
# 0  26917.201375  33247.513229  41276.849187  38807.218575  ...  79030.040075
#
#            2015          2016          2017           2018           2019  \
# 0  83087.360055  85616.083815  91843.154241  103861.651089  109608.305741
#
#            2020          2021           2022           2023
# 0  107658.13103  135773.76902  155350.359037  171041.031694
#
# [1 rows x 24 columns]

# %%
GDP.values.flatten()
# Out:
# array([  7305.6463    ,   8943.5824    ,  10830.5       ,  13208.23377934,
#         17027.1908603 ,  21609.76548933,  26917.2013751 ,  33247.51322882,
#         41276.84918703,  38807.21857476,  46308.54118992,  55967.2267624 ,
#         68103.44962768,  72985.7011301 ,  79030.04007543,  83087.3600554 ,
#         85616.08381474,  91843.15424135, 103861.65108925, 109608.30574101,
#        107658.13102957, 135773.76902038, 155350.35903744, 171041.03169388])

# %% [markdown]
# важно отметить, что, начиная с 1998 года ВВП представлен в млрд. рублей

# %% [markdown]
# ### Plot GDP

# %%
sns.set_style({'axes.facecolor':'23606E',
               'figure.facecolor': '23606E', 
               'axes.labelcolor': 'F5F5F5',
               'axes.axisbelow': True,
               'axes.edgecolor': '327E8F',
               'text.color':'F5F5F5',
               'xtick.color': 'F5F5F5',
              'ytick.color': 'F5F5F5',
              'grid.color': '327E8F'})
values = GDP.values.flatten().astype(float)
sns.lineplot(x=years, y=values, color='#FFC0CB')
plt.xticks(years,rotation = 'vertical')
plt.ylabel('млрд. рублей')
plt.grid(True)
plt.title("ВВП России в период с 2000 по 2023 год")
plt.tight_layout()
plt.show()

# %%
(1 - GDP[2008]/GDP[2009])*100
# Out:
# 0   -6.363843
# dtype: float64

# %% [markdown]
# Мы видим, что ВВП в среднем растет. На графике видны последствия нескольких кризисов: в 2009 году ВВП упал на 6% относительно прошлого года – последствие кризиса 2008 года, и только к 2011 году он вышел на прежний уровень роста, но после 2014 года снова темпы роста снизились.
# В 2020 году ВВП упал, могу предположить, что причиной стала пандемия короновируса, но послее нее темпы роста ВВП сильно увеличились. Найти этому объяснение я не могу.

# %% [markdown]
# ### GDP and inflation
# для подсчета реального ВВП нам необходимы данные о дефляции

# %%
defl = pd.read_excel("data/Rosstat National Accounts 1995.xlsx", sheet_name=9,skiprows=2)

# %%
defl = pd.concat([defl, pd.DataFrame(pd.read_excel("data/Rosstat National Accounts 1995.xlsx", sheet_name= 10,skiprows=2))], axis=1)

# %%
defl = defl.iloc[:,4:]

# %%
real_GDP = GDP*100/defl

# %%
defl
# Out:
#          2000        2001        2002        2003        2004        2005  \
# 0  137.640882  116.489519  115.613926  113.780061  120.282077  119.306095
#
#          2006        2007        2008        2009  ...        2014       2015  \
# 0  115.170047  113.804421  117.959714  101.993723  ...  107.490124  107.24963
#
#          2016        2017        2018        2019       2020        2021  \
# 0  102.844272  105.349763  109.998948  103.263187  100.89827  119.126828
#
#          2022        2023
# 0  115.809703  106.290062
#
# [1 rows x 24 columns]

# %%
plt.plot(years, real_GDP.values.flatten(),marker= 'o', label="Реальное ВВП")
plt.plot(years, values,marker= 'o', label="Номинальное ВВП")
plt.xticks(range(2000,2024),rotation = 'vertical')
plt.ylabel('млрд. рублей')
plt.legend()
plt.grid(True)
plt.title("Реальное и Номинальное ВВП России в период с 2000 по 2023 год")
plt.show()

# %%
defl
# Out:
#          2000        2001        2002        2003        2004        2005  \
# 0  137.640882  116.489519  115.613926  113.780061  120.282077  119.306095
#
#          2006        2007        2008        2009  ...        2014       2015  \
# 0  115.170047  113.804421  117.959714  101.993723  ...  107.490124  107.24963
#
#          2016        2017        2018        2019       2020        2021  \
# 0  102.844272  105.349763  109.998948  103.263187  100.89827  119.126828
#
#          2022        2023
# 0  115.809703  106.290062
#
# [1 rows x 24 columns]

# %%
plt.plot(years,defl.values.flatten())
plt.title('Значение дефлятора в период с 2000 по 2023 годы')
plt.xticks(range(2000,2024),rotation = 'vertical')
plt.ylabel('%')
plt.grid(True)
plt.plot()
plt.savefig('deflation.png')

# %% [markdown]
# Значение реального ВВП растет вместе с номинальным с периодическими скачками. Посмотрев на график дефлятора, можно сказать, что он не достигает значения выше 20%, что может быть обусловлено действиями государства по его сдерживанию.
# Периоды:
# 2008-2009:
# Глобальный финансовый кризис.
# 2014-2015:
# Снижение цен на нефть.
# 2022-2024:
# Санкции против России.

# %%
# Расчет разницы
values = ((1 - real_GDP.values.flatten() / GDP.values.flatten()) * 100)
values = np.round(values,2)

plt.figure(figsize=(15, 5))
sns.barplot(x=years, y=values, color='skyblue')

# Добавление значений над столбцами
for i, value in enumerate(values):
    plt.text(i, value, f'{value:.2f}%', ha='center', va='bottom')

# Дополнительные настройки
plt.grid(which = 'minor')
plt.title('Разница между реальным и номинальным ВВП (в процентном соотношении)')
plt.xlabel('Год')
plt.ylabel('%')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
